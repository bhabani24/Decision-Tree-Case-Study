# %% [markdown]
# # Decision Tree
#
# ### Iris Data

# %%
# DECISION TREE

# PLOTTING DECISION TREE

import os
import pandas as pd
import matplotlib.pyplot as plt


from sklearn import tree
from sklearn.tree import DecisionTreeClassifier

# %%
os.chdir('D:/MLP_Session_26_JULY/DATASET')

iris = pd.read_csv('iris1.csv')

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     Setosa
# 1             4.9          3.0           1.4          0.2     Setosa
# 2             4.7          3.2           1.3          0.2     Setosa
# 3             4.6          3.1           1.5          0.2     Setosa
# 4             5.0          3.6           1.4          0.2     Setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica
#
# [150 rows x 5 columns]

# %%
# Creating different sets for Independent and Dependent variables

X = iris.iloc[:,:-1]
Y = iris.iloc[:,-1]

# %%
iris.species.value_counts()
# Out:
# Virginica     50
# Setosa        50
# Versicolor    50
# Name: species, dtype: int64

# %%
cl=tree.DecisionTreeClassifier(random_state=123)

# %%
# Fitting the model

cl=cl.fit(X,Y)

# %%
plt.figure(figsize=(15,10))
tree.plot_tree(cl,filled=True)
# Out:
# [Text(418.5, 498.3, 'X[2] <= 2.45\ngini = 0.667\nsamples = 150\nvalue = [50, 50, 50]'),
#  Text(354.11538461538464, 407.70000000000005, 'gini = 0.0\nsamples = 50\nvalue = [50, 0, 0]'),
#  Text(482.8846153846154, 407.70000000000005, 'X[3] <= 1.75\ngini = 0.5\nsamples = 100\nvalue = [0, 50, 50]'),
#  Text(257.53846153846155, 317.1, 'X[2] <= 4.95\ngini = 0.168\nsamples = 54\nvalue = [0, 49, 5]'),
#  Text(128.76923076923077, 226.5, 'X[3] <= 1.65\ngini = 0.041\nsamples = 48\nvalue = [0, 47, 1]'),
#  Text(64.38461538461539, 135.89999999999998, 'gini = 0.0\nsamples = 47\nvalue = [0, 47, 0]'),
#  Text(193.15384615384616, 135.89999999999998, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(386.3076923076923, 226.5, 'X[3] <= 1.55\ngini = 0.444\nsamples = 6\nvalue = [0, 2, 4]'),
#  Text(321.9230769230769, 135.89999999999998, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3]'),
#  Text(450.69230769230774, 135.89999999999998, 'X[0] <= 6.95\ngini = 0.444\nsamples = 3\nvalue = [0, 2, 1]'),
# ...

# %%
print(tree.export_text(cl))
# Out:
# |--- feature_2 <= 2.45
# |   |--- class: Setosa
# |--- feature_2 >  2.45
# |   |--- feature_3 <= 1.75
# |   |   |--- feature_2 <= 4.95
# |   |   |   |--- feature_3 <= 1.65
# |   |   |   |   |--- class: Versicolor
# |   |   |   |--- feature_3 >  1.65
# |   |   |   |   |--- class: Virginica
# |   |   |--- feature_2 >  4.95
# |   |   |   |--- feature_3 <= 1.55
# |   |   |   |   |--- class: Virginica
# |   |   |   |--- feature_3 >  1.55
# |   |   |   |   |--- feature_0 <= 6.95
# |   |   |   |   |   |--- class: Versicolor
# |   |   |   |   |--- feature_0 >  6.95
# |   |   |   |   |   |--- class: Virginica
# |   |--- feature_3 >  1.75
# |   |   |--- feature_2 <= 4.85
# |   |   |   |--- feature_0 <= 5.95
# |   |   |   |   |--- class: Versicolor
# |   |   |   |--- feature_0 >  5.95
# |   |   |   |   |--- class: Virginica
# |   |   |--- feature_2 >  4.85
# |   |   |   |--- class: Virginica

# %%
# PLOTTING DECISION TREE IN RANDOM FOREST

import pandas as pd
import matplotlib.pyplot as plt

from sklearn.datasets import load_iris
from sklearn import tree

from sklearn.ensemble import RandomForestClassifier

# %%
cl=RandomForestClassifier(n_estimators=15, random_state=123)

# %%
cl=cl.fit(X,Y)

# %%
cl.estimators_
# Out:
# [DecisionTreeClassifier(max_features='auto', random_state=843828734),
#  DecisionTreeClassifier(max_features='auto', random_state=914636141),
#  DecisionTreeClassifier(max_features='auto', random_state=1228959102),
#  DecisionTreeClassifier(max_features='auto', random_state=1840268610),
#  DecisionTreeClassifier(max_features='auto', random_state=974319580),
#  DecisionTreeClassifier(max_features='auto', random_state=819844194),
#  DecisionTreeClassifier(max_features='auto', random_state=220395238),
#  DecisionTreeClassifier(max_features='auto', random_state=941243409),
#  DecisionTreeClassifier(max_features='auto', random_state=942612051),
#  DecisionTreeClassifier(max_features='auto', random_state=2109339754),
#  DecisionTreeClassifier(max_features='auto', random_state=1817228411),
#  DecisionTreeClassifier(max_features='auto', random_state=1202710073),
#  DecisionTreeClassifier(max_features='auto', random_state=2064866518),
# ...

# %%
len(cl.estimators_)
# Out:
# 15

# %%
plt.figure(figsize=(15,10))
tree.plot_tree(cl.estimators_[2],filled=True)
# Out:
# [Text(418.5, 509.625, 'X[2] <= 2.45\ngini = 0.666\nsamples = 96\nvalue = [52, 46, 52]'),
#  Text(354.11538461538464, 441.675, 'gini = 0.0\nsamples = 31\nvalue = [52, 0, 0]'),
#  Text(482.8846153846154, 441.675, 'X[0] <= 6.15\ngini = 0.498\nsamples = 65\nvalue = [0, 46, 52]'),
#  Text(257.53846153846155, 373.725, 'X[2] <= 4.75\ngini = 0.439\nsamples = 27\nvalue = [0, 27, 13]'),
#  Text(128.76923076923077, 305.775, 'X[3] <= 1.65\ngini = 0.074\nsamples = 17\nvalue = [0, 25, 1]'),
#  Text(64.38461538461539, 237.825, 'gini = 0.0\nsamples = 16\nvalue = [0, 25, 0]'),
#  Text(193.15384615384616, 237.825, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(386.3076923076923, 305.775, 'X[1] <= 3.1\ngini = 0.245\nsamples = 10\nvalue = [0, 2, 12]'),
#  Text(321.9230769230769, 237.825, 'X[0] <= 6.05\ngini = 0.142\nsamples = 9\nvalue = [0, 1, 12]'),
#  Text(257.53846153846155, 169.875, 'X[0] <= 5.95\ngini = 0.219\nsamples = 7\nvalue = [0, 1, 7]'),
# ...

# %%
plt.figure(figsize=(15,10))

for i in range(len(cl.estimators_)):
    tree.plot_tree(cl.estimators_[i],filled=True)

for i in range(len(cl.estimators_)):
    print(tree.export_text(cl.estimators_[i]))
# Out:
# |--- feature_0 <= 5.45
# |   |--- feature_2 <= 2.45
# |   |   |--- class: 0.0
# |   |--- feature_2 >  2.45
# |   |   |--- class: 1.0
# |--- feature_0 >  5.45
# |   |--- feature_3 <= 1.75
# |   |   |--- feature_2 <= 2.60
# |   |   |   |--- class: 0.0
# |   |   |--- feature_2 >  2.60
# |   |   |   |--- feature_2 <= 5.05
# |   |   |   |   |--- class: 1.0
# |   |   |   |--- feature_2 >  5.05
# |   |   |   |   |--- feature_0 <= 6.15
# |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |--- feature_0 >  6.15
# |   |   |   |   |   |--- class: 2.0
# |   |--- feature_3 >  1.75
# |   |   |--- feature_0 <= 5.95
# |   |   |   |--- feature_3 <= 1.85
# |   |   |   |   |--- class: 1.0
# |   |   |   |--- feature_3 >  1.85
# |   |   |   |   |--- class: 2.0
# |   |   |--- feature_0 >  5.95
# |   |   |   |--- class: 2.0
#
# |--- feature_2 <= 2.35
# |   |--- class: 0.0
# |--- feature_2 >  2.35
# |   |--- feature_2 <= 4.95
# |   |   |--- feature_2 <= 4.75
# |   |   |   |--- feature_3 <= 1.65
# ...
